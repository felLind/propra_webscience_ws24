# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.neighbors import KNeighborsClassifier
import sklearn.metrics as metrics
from sklearn.model_selection import GridSearchCV

# %%
# Constants
TRAIN_DATA_NAME = 'sentiment140/sentiment140_training.csv'
TRAIN_COLUMN_NAMES = ['sentiment', 'tweets']

TEST_DATA_NAME = 'sentiment140/sentiment140_test.csv'
TEST_COLUMN_NAMES = ['sentiment', 'tweets']

ENCODING = 'latin-1'
NROWS = 1600000

pd.options.display.max_colwidth = None

# %%
train_df = pd.read_csv(
    TRAIN_DATA_NAME,
    encoding=ENCODING,
    header=0,
    names=TRAIN_COLUMN_NAMES,
    nrows=NROWS
    )

print('TRAIN DATASET: \n', train_df.head(4))


test_df = pd.read_csv(
    TEST_DATA_NAME,
    encoding=ENCODING,
    header=0,
    names=TEST_COLUMN_NAMES,
    nrows=NROWS
    )

print('\nTEST DATASET: \n', test_df.head(4))
# Out:
# TRAIN DATASET:
#     sentiment  \
# 0          0
# 1          0
# 2          0
# 3          0
#
#                                                                                                                 tweets
# 0  @switchfoot http://twitpic.com/2y1zl - Awww, that's a bummer.  You shoulda got David Carr of Third Day to do it. ;D
# 1      is upset that he can't update his Facebook by texting it... and might cry as a result  School today also. Blah!
# 2                            @Kenichan I dived many times for the ball. Managed to save 50%  The rest go out of bounds
# 3                                                                      my whole body feels itchy and like its on fire
#
# TEST DATASET:
#     sentiment  \
# 0          4
# 1          4
# 2          4
# 3          4
#
#                                                                                                                                          tweets
# 0                               @stellargirl I loooooooovvvvvveee my Kindle2. Not that the DX is cool, but the 2 is fantastic in its own right.
# 1                                                                                    Reading my kindle2...  Love it... Lee childs is good read.
# 2                                                                                    Ok, first assesment of the #kindle2 ...it fucking rocks!!!
# 3  @kenburbary You'll love your Kindle2. I've had mine for a few months and never looked back. The new big one is huge! No need for remorse! :)

# %%
dataset_variations = [
    'cleaned_w_apostrophe_t_w_r_lem',
    'cleaned_w_apostrophe_t_wo_r_lem',
    'cleaned_wo_apostrophe_t_w_r_lem',
    'cleaned_wo_apostrophe_t_wo_r_lem', 
    'cleaned_w_apostrophe_t_w_r_stem',
    'cleaned_w_apostrophe_t_wo_r_stem', 
    'cleaned_wo_apostrophe_t_w_r_stem', 
    'cleaned_wo_apostrophe_t_wo_r_stem'
    ]

# %%
# Bag of Words model
vectorizer = CountVectorizer(max_features=10000)
BoWvectorizer = vectorizer.fit(train_df.tweets)

X_train_bow = BoWvectorizer.transform(train_df.tweets)
X_test_bow = BoWvectorizer.transform(test_df.tweets)
# Out:
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\Anne\AppData\Local\Temp\ipykernel_21352\685721583.py", line 3, in <module>
#     BoWvectorizer = vectorizer.fit(train_df.tweets)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\sklearn\feature_extraction\text.py", line 1323, in fit
#     self.fit_transform(raw_documents)
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\sklearn\feature_extraction\text.py", line 1372, in fit_transform
#     vocabulary, X = self._count_vocab(raw_documents, self.fixed_vocabulary_)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\sklearn\feature_extraction\text.py", line -1, in _count_vocab
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\IPython\core\interactiveshell.py", line 2120, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\IPython\core\ultratb.py", line 1435, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\IPython\core\ultratb.py", line 1326, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\IPython\core\ultratb.py", line 1173, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\IPython\core\ultratb.py", line 1088, in format_exception_as_a_whole
#     frames.append(self.format_record(record))
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\IPython\core\ultratb.py", line 970, in format_record
#     frame_info.lines, Colors, self.has_colors, lvals
#     ^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\IPython\core\ultratb.py", line 792, in lines
#     return self._sd.lines
#            ^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#            ^^^^^
#   File "c:\Users\Anne\miniconda3\envs\ds\Lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
clf_knn1 = KNeighborsClassifier(n_neighbors=1, metric='minkowski', p=1).fit(X_train_bow, train_df.sentiment)
clf_knn3 = KNeighborsClassifier(n_neighbors=3, metric='minkowski', p=1).fit(X_train_bow, train_df.sentiment)
clf_knn5 = KNeighborsClassifier(n_neighbors=5, metric='minkowski', p=1).fit(X_train_bow, train_df.sentiment)
clf_knn7 = KNeighborsClassifier(n_neighbors=7, metric='minkowski', p=1).fit(X_train_bow, train_df.sentiment)

# %%
pred_X_test1 = clf_knn1.predict(X_test_bow)
pred_X_test3 = clf_knn3.predict(X_test_bow)
pred_X_test5 = clf_knn5.predict(X_test_bow)
pred_X_test7 = clf_knn7.predict(X_test_bow)

# %%
print('classification report test\n', metrics.classification_report(test_df.sentiment, pred_X_test1))
print('test accuracy', metrics.accuracy_score(test_df.sentiment, pred_X_test1))

print('test accuracy1', metrics.accuracy_score(test_df.sentiment, pred_X_test1))
print('test accuracy3', metrics.accuracy_score(test_df.sentiment, pred_X_test3))
print('test accuracy5', metrics.accuracy_score(test_df.sentiment, pred_X_test5))
print('test accuracy7', metrics.accuracy_score(test_df.sentiment, pred_X_test7))
# Out:
# classification report test
#                precision    recall  f1-score   support
#
#            0       0.63      0.75      0.68       177
#            4       0.70      0.57      0.63       182
#
#     accuracy                           0.66       359
#    macro avg       0.66      0.66      0.65       359
# weighted avg       0.66      0.66      0.65       359
#
# test accuracy 0.6573816155988857
# test accuracy1 0.6573816155988857
# test accuracy3 0.6740947075208914
# test accuracy5 0.6657381615598886
# test accuracy7 0.6824512534818942

# %% [markdown]
# train und test datensatz laden
# train test split machen
# boW
# clf trainieren
# predicten
#
#
# # GridSearch
# train und test Datensaetze laden
# bow
# gridsearch:
# mit den besten parametern am testdatensatz testen: accuracy

# %%
def load_train_and_test_dataset(dataset_name):

    train_filename = 'sentiment140/sentiment140_train_' + dataset_name + '.csv'
    test_filename = 'sentiment140/sentiment140_test_' + dataset_name + '.csv'


    train_df = pd.read_csv(
        train_filename,
        encoding=ENCODING,
        header=0,
        names=TRAIN_COLUMN_NAMES,
        nrows=NROWS
    )

    test_df = pd.read_csv(
        test_filename,
        encoding=ENCODING,
        header=0,
        names=TEST_COLUMN_NAMES,
        nrows=NROWS
    )

    return train_df, test_df

# %%
# Bag of Words model

def bow_model(X_train, X_test):
    vectorizer = CountVectorizer(max_features=15000)
    BoWvectorizer = vectorizer.fit(X_train)

    X_train_bow = BoWvectorizer.transform(X_train)
    X_test_bow = BoWvectorizer.transform(X_test)

    return X_train_bow, X_test_bow

# %%
def train_predict_metrics(name, metrics_array, X_train_bow, y_train, X_test_bow, y_test):
    for neighbor in range(1,15,2):
        for p in [1,2]:
            
            # classifier
            clf_knn = KNeighborsClassifier(n_neighbors=neighbor, metric='minkowski', p=p).fit(X_train_bow, y_train)

            # test data predictions
            pred_X_test = clf_knn.predict(X_test_bow)

            # Test Dataset Metrics
            metrics_array.append([
                name, 
                neighbor, 
                p, 
                round(metrics.accuracy_score(y_test, pred_X_test), 4),
                round(metrics.precision_score(y_test, pred_X_test, pos_label=4), 4),
                round(metrics.recall_score(y_test, pred_X_test, pos_label=4), 4),
                round(metrics.f1_score(y_test, pred_X_test, pos_label=4), 4)
            ])

# %%
metrics_array = []

for dataset_name in dataset_variations:
    print('Dataset: ', dataset_name)

    train_df, test_df = load_train_and_test_dataset(dataset_name)

    X_train = train_df.tweets
    X_test = test_df.tweets
    y_train = train_df.sentiment
    y_test = test_df.sentiment

    X_train_bow, X_test_bow = bow_model(X_train, X_test)

    train_predict_metrics(dataset_name, metrics_array, X_train_bow, y_train, X_test_bow, y_test)
# Out:
# Dataset:  cleaned_w_apostrophe_t_w_r_lem
# Dataset:  cleaned_w_apostrophe_t_wo_r_lem
# Dataset:  cleaned_wo_apostrophe_t_w_r_lem
# Dataset:  cleaned_wo_apostrophe_t_wo_r_lem
# Dataset:  cleaned_w_apostrophe_t_w_r_stem
# Dataset:  cleaned_w_apostrophe_t_wo_r_stem
# Dataset:  cleaned_wo_apostrophe_t_w_r_stem
# Dataset:  cleaned_wo_apostrophe_t_wo_r_stem

# %%
metrics_array
# Out:
# [['cleaned_w_apostrophe_t_w_r_lem', 1, 1, 0.6713, 0.7963, 0.4725, 0.5931],
#  ['cleaned_w_apostrophe_t_w_r_lem', 1, 2, 0.6657, 0.7818, 0.4725, 0.589],
#  ['cleaned_w_apostrophe_t_w_r_lem', 3, 1, 0.6741, 0.8095, 0.467, 0.5923],
#  ['cleaned_w_apostrophe_t_w_r_lem', 3, 2, 0.663, 0.7905, 0.456, 0.5784],
#  ['cleaned_w_apostrophe_t_w_r_lem', 5, 1, 0.7019, 0.6596, 0.8516, 0.7434],
#  ['cleaned_w_apostrophe_t_w_r_lem', 5, 2, 0.7019, 0.6638, 0.8352, 0.7397],
#  ['cleaned_w_apostrophe_t_w_r_lem', 7, 1, 0.7075, 0.6652, 0.8516, 0.747],
#  ['cleaned_w_apostrophe_t_w_r_lem', 7, 2, 0.7103, 0.6741, 0.8297, 0.7438],
#  ['cleaned_w_apostrophe_t_w_r_lem', 9, 1, 0.7019, 0.6596, 0.8516, 0.7434],
#  ['cleaned_w_apostrophe_t_w_r_lem', 9, 2, 0.7131, 0.6725, 0.8462, 0.7494],
#  ['cleaned_w_apostrophe_t_w_r_lem', 11, 1, 0.7019, 0.6569, 0.8626, 0.7458],
#  ['cleaned_w_apostrophe_t_w_r_lem', 11, 2, 0.7103, 0.6741, 0.8297, 0.7438],
#  ['cleaned_w_apostrophe_t_w_r_lem', 13, 1, 0.7103, 0.6598, 0.8846, 0.7559],
#  ['cleaned_w_apostrophe_t_w_r_lem', 13, 2, 0.7131, 0.6756, 0.8352, 0.7469],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 1, 1, 0.6574, 0.7218, 0.5275, 0.6095],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 1, 2, 0.6546, 0.7132, 0.533, 0.6101],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 3, 1, 0.6602, 0.7206, 0.5385, 0.6164],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 3, 2, 0.6602, 0.7143, 0.5495, 0.6211],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 5, 1, 0.6769, 0.6341, 0.8571, 0.729],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 5, 2, 0.6825, 0.6417, 0.8462, 0.7299],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 7, 1, 0.6685, 0.6245, 0.8681, 0.7264],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 7, 2, 0.6992, 0.6555, 0.8571, 0.7429],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 9, 1, 0.6741, 0.6327, 0.8516, 0.726],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 9, 2, 0.6936, 0.6513, 0.8516, 0.7381],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 11, 1, 0.6852, 0.6397, 0.8681, 0.7366],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 11, 2, 0.6825, 0.6405, 0.8516, 0.7311],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 13, 1, 0.6964, 0.6478, 0.8791, 0.7459],
#  ['cleaned_w_apostrophe_t_wo_r_lem', 13, 2, 0.6908, 0.6461, 0.8626, 0.7388],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 1, 1, 0.6685, 0.789, 0.4725, 0.5911],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 1, 2, 0.6685, 0.7788, 0.4835, 0.5966],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 3, 1, 0.649, 0.78, 0.4286, 0.5532],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 3, 2, 0.6462, 0.767, 0.4341, 0.5544],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 5, 1, 0.7075, 0.6667, 0.8462, 0.7458],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 5, 2, 0.6936, 0.6565, 0.8297, 0.733],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 7, 1, 0.7075, 0.6681, 0.8407, 0.7445],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 7, 2, 0.727, 0.6909, 0.8352, 0.7562],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 9, 1, 0.7131, 0.671, 0.8516, 0.7506],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 9, 2, 0.6992, 0.6623, 0.8297, 0.7366],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 11, 1, 0.7298, 0.684, 0.8681, 0.7651],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 11, 2, 0.6908, 0.6524, 0.8352, 0.7325],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 13, 1, 0.7214, 0.6737, 0.8736, 0.7608],
#  ['cleaned_wo_apostrophe_t_w_r_lem', 13, 2, 0.6936, 0.6538, 0.8407, 0.7356],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 1, 1, 0.6574, 0.7218, 0.5275, 0.6095],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 1, 2, 0.6546, 0.7132, 0.533, 0.6101],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 3, 1, 0.6574, 0.7185, 0.533, 0.612],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 3, 2, 0.6602, 0.7143, 0.5495, 0.6211],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 5, 1, 0.7075, 0.6598, 0.8736, 0.7518],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 5, 2, 0.6936, 0.6513, 0.8516, 0.7381],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 7, 1, 0.7187, 0.6709, 0.8736, 0.7589],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 7, 2, 0.6936, 0.65, 0.8571, 0.7393],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 9, 1, 0.7187, 0.6653, 0.8956, 0.7635],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 9, 2, 0.7047, 0.657, 0.8736, 0.75],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 11, 1, 0.727, 0.6694, 0.9121, 0.7721],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 11, 2, 0.688, 0.6446, 0.8571, 0.7358],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 13, 1, 0.7047, 0.6532, 0.8901, 0.7535],
#  ['cleaned_wo_apostrophe_t_wo_r_lem', 13, 2, 0.6797, 0.6356, 0.8626, 0.7319],
#  ['cleaned_w_apostrophe_t_w_r_stem', 1, 1, 0.6825, 0.8148, 0.4835, 0.6069],
#  ['cleaned_w_apostrophe_t_w_r_stem', 1, 2, 0.6769, 0.8056, 0.478, 0.6],
#  ['cleaned_w_apostrophe_t_w_r_stem', 3, 1, 0.6657, 0.7981, 0.456, 0.5804],
#  ['cleaned_w_apostrophe_t_w_r_stem', 3, 2, 0.6546, 0.7685, 0.456, 0.5724],
#  ['cleaned_w_apostrophe_t_w_r_stem', 5, 1, 0.7549, 0.7238, 0.8352, 0.7755],
#  ['cleaned_w_apostrophe_t_w_r_stem', 5, 2, 0.7214, 0.6847, 0.8352, 0.7525],
#  ['cleaned_w_apostrophe_t_w_r_stem', 7, 1, 0.7409, 0.6978, 0.8626, 0.7715],
#  ['cleaned_w_apostrophe_t_w_r_stem', 7, 2, 0.6992, 0.6623, 0.8297, 0.7366],
#  ['cleaned_w_apostrophe_t_w_r_stem', 9, 1, 0.7298, 0.6872, 0.8571, 0.7628],
#  ['cleaned_w_apostrophe_t_w_r_stem', 9, 2, 0.7047, 0.6667, 0.8352, 0.7415],
#  ['cleaned_w_apostrophe_t_w_r_stem', 11, 1, 0.7354, 0.6916, 0.8626, 0.7677],
#  ['cleaned_w_apostrophe_t_w_r_stem', 11, 2, 0.6964, 0.6608, 0.8242, 0.7335],
#  ['cleaned_w_apostrophe_t_w_r_stem', 13, 1, 0.7382, 0.693, 0.8681, 0.7707],
#  ['cleaned_w_apostrophe_t_w_r_stem', 13, 2, 0.7214, 0.6798, 0.8516, 0.7561],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 1, 1, 0.663, 0.7075, 0.5714, 0.6322],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 1, 2, 0.649, 0.6918, 0.5549, 0.6159],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 3, 1, 0.6769, 0.7292, 0.5769, 0.6442],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 3, 2, 0.6769, 0.7292, 0.5769, 0.6442],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 5, 1, 0.6908, 0.6511, 0.8407, 0.7338],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 5, 2, 0.6797, 0.6379, 0.8516, 0.7294],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 7, 1, 0.6741, 0.6371, 0.8297, 0.7208],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 7, 2, 0.6657, 0.625, 0.8516, 0.7209],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 9, 1, 0.6741, 0.636, 0.8352, 0.7221],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 9, 2, 0.6602, 0.621, 0.8462, 0.7163],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 11, 1, 0.6825, 0.6417, 0.8462, 0.7299],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 11, 2, 0.6657, 0.623, 0.8626, 0.7235],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 13, 1, 0.6825, 0.6429, 0.8407, 0.7286],
#  ['cleaned_w_apostrophe_t_wo_r_stem', 13, 2, 0.6657, 0.624, 0.8571, 0.7222],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 1, 1, 0.6852, 0.8053, 0.5, 0.6169],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 1, 2, 0.6769, 0.7946, 0.489, 0.6054],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 3, 1, 0.6518, 0.7879, 0.4286, 0.5552],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 3, 2, 0.6407, 0.7524, 0.4341, 0.5505],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 5, 1, 0.7242, 0.6844, 0.8462, 0.7568],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 5, 2, 0.7075, 0.6681, 0.8407, 0.7445],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 7, 1, 0.7298, 0.6856, 0.8626, 0.764],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 7, 2, 0.6964, 0.658, 0.8352, 0.7361],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 9, 1, 0.7382, 0.688, 0.8846, 0.774],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 9, 2, 0.7075, 0.6681, 0.8407, 0.7445],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 11, 1, 0.7187, 0.6753, 0.8571, 0.7554],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 11, 2, 0.7019, 0.6638, 0.8352, 0.7397],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 13, 1, 0.7214, 0.6737, 0.8736, 0.7608],
#  ['cleaned_wo_apostrophe_t_w_r_stem', 13, 2, 0.7326, 0.6886, 0.8626, 0.7659],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 1, 1, 0.6657, 0.7095, 0.5769, 0.6364],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 1, 2, 0.6518, 0.6939, 0.5604, 0.6201],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 3, 1, 0.6713, 0.7192, 0.5769, 0.6402],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 3, 2, 0.6713, 0.7222, 0.5714, 0.638],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 5, 1, 0.6908, 0.6437, 0.8736, 0.7413],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 5, 2, 0.6685, 0.6296, 0.8407, 0.72],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 7, 1, 0.6964, 0.649, 0.8736, 0.7447],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 7, 2, 0.6825, 0.6393, 0.8571, 0.7324],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 9, 1, 0.7047, 0.6545, 0.8846, 0.7523],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 9, 2, 0.6964, 0.6466, 0.8846, 0.7471],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 11, 1, 0.7047, 0.6532, 0.8901, 0.7535],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 11, 2, 0.6852, 0.6375, 0.8791, 0.739],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 13, 1, 0.7047, 0.6532, 0.8901, 0.7535],
#  ['cleaned_wo_apostrophe_t_wo_r_stem', 13, 2, 0.6797, 0.6314, 0.8846, 0.7368]]

# %%
metrics_df = pd.DataFrame(metrics_array, columns=['dataset_name', 'neighbors', 'p', 'accuracy', 'precision', 'recall', 'f1'])
metrics_df
# Out:
#                           dataset_name  neighbors  p  accuracy  precision  \
# 0       cleaned_w_apostrophe_t_w_r_lem          1  1    0.6713     0.7963
# 1       cleaned_w_apostrophe_t_w_r_lem          1  2    0.6657     0.7818
# 2       cleaned_w_apostrophe_t_w_r_lem          3  1    0.6741     0.8095
# 3       cleaned_w_apostrophe_t_w_r_lem          3  2    0.6630     0.7905
# 4       cleaned_w_apostrophe_t_w_r_lem          5  1    0.7019     0.6596
# ..                                 ...        ... ..       ...        ...
# 107  cleaned_wo_apostrophe_t_wo_r_stem          9  2    0.6964     0.6466
# 108  cleaned_wo_apostrophe_t_wo_r_stem         11  1    0.7047     0.6532
# 109  cleaned_wo_apostrophe_t_wo_r_stem         11  2    0.6852     0.6375
# 110  cleaned_wo_apostrophe_t_wo_r_stem         13  1    0.7047     0.6532
# 111  cleaned_wo_apostrophe_t_wo_r_stem         13  2    0.6797     0.6314
#
#      recall      f1
# 0    0.4725  0.5931
# 1    0.4725  0.5890
# 2    0.4670  0.5923
# 3    0.4560  0.5784
# 4    0.8516  0.7434
# ..      ...     ...
# 107  0.8846  0.7471
# 108  0.8901  0.7535
# 109  0.8791  0.7390
# 110  0.8901  0.7535
# 111  0.8846  0.7368
#
# [112 rows x 7 columns]

# %%
max_acc_value = metrics_df.accuracy.max()
metrics_df.iloc[metrics_df.accuracy.idxmax()]
# Out:
# dataset_name    cleaned_w_apostrophe_t_w_r_stem
# neighbors                                     5
# p                                             1
# accuracy                                 0.7549
# precision                                0.7238
# recall                                   0.8352
# f1                                       0.7755
# Name: 60, dtype: object

# %%
PARAM_GRID = {
                'n_neighbors': [1],
                'p': [1],
                'weights': ['uniform'],
                'metric': ['minkowski']
              }


grid = GridSearchCV(
                    estimator=KNeighborsClassifier(),
                    param_grid=PARAM_GRID,
                    scoring='accuracy',
                    n_jobs=-1,
                    refit=True,
                    cv=2,
                    verbose=10
                    )

grid.fit(X_train_bow[720000:880000], y_train[720000:880000])
# Out:
# Fitting 2 folds for each of 1 candidates, totalling 2 fits
# GridSearchCV(cv=2, estimator=KNeighborsClassifier(), n_jobs=-1,
#              param_grid={'metric': ['minkowski'], 'n_neighbors': [1], 'p': [1],
#                          'weights': ['uniform']},
#              scoring='accuracy', verbose=10)

# %%
# Results
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'metric': 'minkowski', 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}
# 0.61444375
