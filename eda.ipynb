# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Twitter Sentiment Analysis
#
# The goal of this project is to use ML models to predict the Sentiment of Tweets.
#
# Data Source: https://www.kaggle.com/datasets/kazanova/sentiment140/data
#
# Sentiment140: Go, A., Bhayani, R. and Huang, L., 2009. Twitter sentiment classification using distant supervision. CS224N Project Report, Stanford, 1(2009), p.12.

# %% [markdown]
# ## Examining Initial Dataset
#
# We are not limited to this dataset for this project. Additional data might be needed.
#
# According to the author of this dataset, the tweets were collected by scraping tweets with emoticons and labelling the tweets according to these emoticons. The emoticons have been removed after labeling the data.

# %%
# load dataset
# df = pd.read_csv('datasets/twitter_training.csv',names=['ID', 'entity', 'sentiment', 'tweet'])
df = pd.read_csv('datasets/sentiment140.csv', names=['sentiment', 'id', 'date', 'query', 'user', 'text'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   sentiment  1600000 non-null  int64
#  1   id         1600000 non-null  int64
#  2   date       1600000 non-null  object
#  3   query      1600000 non-null  object
#  4   user       1600000 non-null  object
#  5   text       1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB

# %%
df.head(10)
# Out:
#    sentiment          id                          date     query  \
# 0          0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1          0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2          0  1467810917  Mon Apr 06 22:19:53 PDT 2009  NO_QUERY
# 3          0  1467811184  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 4          0  1467811193  Mon Apr 06 22:19:57 PDT 2009  NO_QUERY
# 5          0  1467811372  Mon Apr 06 22:20:00 PDT 2009  NO_QUERY
# 6          0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 7          0  1467811594  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 8          0  1467811795  Mon Apr 06 22:20:05 PDT 2009  NO_QUERY
# 9          0  1467812025  Mon Apr 06 22:20:09 PDT 2009  NO_QUERY
#
#               user                                               text
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2         mattycus  @Kenichan I dived many times for the ball. Man...
# 3          ElleCTF    my whole body feels itchy and like its on fire
# 4           Karoli  @nationwideclass no, it's not behaving at all....
# 5         joy_wolf                      @Kwesidei not the whole crew
# 6          mybirch                                        Need a hug
# 7             coZZ  @LOLTrish hey  long time no see! Yes.. Rains a...
# 8  2Hood4Hollywood               @Tatiana_K nope they didn't have it
# 9          mimismo                          @twittera que me muera ?

# %%
df['id'].value_counts()
# Out:
# 2190457769    2
# 1972193428    2
# 1989776729    2
# 1989776908    2
# 1564543229    2
#              ..
# 2197311196    1
# 2197311146    1
# 2197310899    1
# 2197310477    1
# 2193602129    1
# Name: id, Length: 1598315, dtype: int64

# %% [markdown]
# ## Pre-trained model
#
# We use the pre-trained model as a reference for the following models and to demonstrate how easy and accurate the use of pre-trained models is for well researched tasks.
#
# HF link: https://huggingface.co/cardiffnlp/twitter-roberta-base-sentiment-latest

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

sentiment_analysis = pipeline("text-classification", model="cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# Downloading:   0%|          | 0.00/929 [00:00<?, ?B/s]
# c:\Users\Burak.Oezkan\anaconda3\lib\site-packages\huggingface_hub\file_download.py:123: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\Burak.Oezkan\.cache\huggingface\hub. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading:   0%|          | 0.00/501M [00:00<?, ?B/s]
# Some weights of the model checkpoint at cardiffnlp/twitter-roberta-base-sentiment-latest were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Downloading:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/239 [00:00<?, ?B/s]

# %%
# Example usage
sentiment_analysis("I love you")
# Out:
# [{'label': 'positive', 'score': 0.8594695329666138}]

# %%
df_example = df.head(30).copy()
df_example['predicted_sentiment'] = df_example['text'].apply(sentiment_analysis)

# %%
df_example.iloc[:, [0, 5, 6]]
# Out:
#     sentiment                                               text  \
# 0           0  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1           0  is upset that he can't update his Facebook by ...
# 2           0  @Kenichan I dived many times for the ball. Man...
# 3           0    my whole body feels itchy and like its on fire
# 4           0  @nationwideclass no, it's not behaving at all....
# 5           0                      @Kwesidei not the whole crew
# 6           0                                        Need a hug
# 7           0  @LOLTrish hey  long time no see! Yes.. Rains a...
# 8           0               @Tatiana_K nope they didn't have it
# 9           0                          @twittera que me muera ?
# 10          0        spring break in plain city... it's snowing
# 11          0                         I just re-pierced my ears
# 12          0  @caregiving I couldn't bear to watch it.  And ...
# 13          0  @octolinz16 It it counts, idk why I did either...
# 14          0  @smarrison i would've been the first, but i di...
# 15          0  @iamjazzyfizzle I wish I got to watch it with ...
# 16          0  Hollis' death scene will hurt me severely to w...
# 17          0                               about to file taxes
# 18          0  @LettyA ahh ive always wanted to see rent  lov...
# 19          0  @FakerPattyPattz Oh dear. Were you drinking ou...
# 20          0  @alydesigns i was out most of the day so didn'...
# 21          0  one of my friend called me, and asked to meet ...
# 22          0   @angry_barista I baked you a cake but I ated it
# 23          0             this week is not going as i had hoped
# 24          0                         blagh class at 8 tomorrow
# 25          0     I hate when I have to call and wake people up
# 26          0  Just going to cry myself to sleep after watchi...
# 27          0                             im sad now  Miss.Lilly
# 28          0  ooooh.... LOL  that leslie.... and ok I won't ...
# 29          0  Meh... Almost Lover is the exception... this t...
#
#                                   predicted_sentiment
# 0   [{'label': 'negative', 'score': 0.745751440525...
# 1   [{'label': 'negative', 'score': 0.900523424148...
# 2   [{'label': 'neutral', 'score': 0.6559894084930...
# 3   [{'label': 'negative', 'score': 0.897633254528...
# 4   [{'label': 'negative', 'score': 0.931198000907...
# 5   [{'label': 'neutral', 'score': 0.6053249835968...
# 6   [{'label': 'neutral', 'score': 0.6586580872535...
# 7   [{'label': 'positive', 'score': 0.922187566757...
# 8   [{'label': 'neutral', 'score': 0.5189148783683...
# 9   [{'label': 'neutral', 'score': 0.8834701180458...
# 10  [{'label': 'neutral', 'score': 0.6654297113418...
# 11  [{'label': 'neutral', 'score': 0.7556750178337...
# 12  [{'label': 'negative', 'score': 0.942754328250...
# 13  [{'label': 'negative', 'score': 0.845712184906...
# 14  [{'label': 'negative', 'score': 0.783901751041...
# 15  [{'label': 'positive', 'score': 0.847045183181...
# 16  [{'label': 'negative', 'score': 0.913828372955...
# 17  [{'label': 'neutral', 'score': 0.8759663701057...
# 18  [{'label': 'positive', 'score': 0.986928403377...
# 19  [{'label': 'negative', 'score': 0.612220823764...
# 20  [{'label': 'negative', 'score': 0.663417935371...
# 21  [{'label': 'negative', 'score': 0.608786523342...
# 22  [{'label': 'neutral', 'score': 0.6540986895561...
# 23  [{'label': 'negative', 'score': 0.900241613388...
# 24  [{'label': 'neutral', 'score': 0.9467618465423...
# 25  [{'label': 'negative', 'score': 0.903715908527...
# 26  [{'label': 'neutral', 'score': 0.4954183101654...
# 27  [{'label': 'negative', 'score': 0.886352360248...
# 28  [{'label': 'neutral', 'score': 0.4165870249271...
# 29  [{'label': 'negative', 'score': 0.925571680068...

# %% [markdown]
# ## Possible pre-processing steps

# %%
# One straight forward step is the removal of the @username
# The username could be very impactful for the model but is not relevant for the actual sentiment of the tweet

def remove_username(text):
    return ' '.join(word for word in text.split() if not word.startswith('@'))

df_example['text'] = df_example['text'].apply(remove_username)
df_example['predicted_sentiment'] = df_example['text'].apply(sentiment_analysis)
df_example.iloc[:, [0, 5, 6]]
# Out:
#     sentiment                                               text  \
# 0           0  http://twitpic.com/2y1zl - Awww, that's a bumm...
# 1           0  is upset that he can't update his Facebook by ...
# 2           0  I dived many times for the ball. Managed to sa...
# 3           0     my whole body feels itchy and like its on fire
# 4           0  no, it's not behaving at all. i'm mad. why am ...
# 5           0                                 not the whole crew
# 6           0                                         Need a hug
# 7           0  hey long time no see! Yes.. Rains a bit ,only ...
# 8           0                           nope they didn't have it
# 9           0                                     que me muera ?
# 10          0         spring break in plain city... it's snowing
# 11          0                          I just re-pierced my ears
# 12          0  I couldn't bear to watch it. And I thought the...
# 13          0  It it counts, idk why I did either. you never ...
# 14          0  i would've been the first, but i didn't have a...
# 15          0  I wish I got to watch it with you!! I miss you...
# 16          0  Hollis' death scene will hurt me severely to w...
# 17          0                                about to file taxes
# 18          0  ahh ive always wanted to see rent love the sou...
# 19          0  Oh dear. Were you drinking out of the forgotte...
# 20          0  i was out most of the day so didn't get much done
# 21          0  one of my friend called me, and asked to meet ...
# 22          0                   I baked you a cake but I ated it
# 23          0              this week is not going as i had hoped
# 24          0                          blagh class at 8 tomorrow
# 25          0      I hate when I have to call and wake people up
# 26          0  Just going to cry myself to sleep after watchi...
# 27          0                              im sad now Miss.Lilly
# 28          0  ooooh.... LOL that leslie.... and ok I won't d...
# 29          0  Meh... Almost Lover is the exception... this t...
#
#                                   predicted_sentiment
# 0   [{'label': 'negative', 'score': 0.771735787391...
# 1   [{'label': 'negative', 'score': 0.905853092670...
# 2   [{'label': 'neutral', 'score': 0.6504483222961...
# 3   [{'label': 'negative', 'score': 0.880418777465...
# 4   [{'label': 'negative', 'score': 0.912394821643...
# 5   [{'label': 'neutral', 'score': 0.5887722969055...
# 6   [{'label': 'neutral', 'score': 0.4998500347137...
# 7   [{'label': 'positive', 'score': 0.906500339508...
# 8   [{'label': 'neutral', 'score': 0.4911064505577...
# 9   [{'label': 'neutral', 'score': 0.8560315370559...
# 10  [{'label': 'neutral', 'score': 0.5978688597679...
# 11  [{'label': 'neutral', 'score': 0.6799874901771...
# 12  [{'label': 'negative', 'score': 0.938758790493...
# 13  [{'label': 'negative', 'score': 0.810551583766...
# 14  [{'label': 'negative', 'score': 0.776177942752...
# 15  [{'label': 'positive', 'score': 0.891458809375...
# 16  [{'label': 'negative', 'score': 0.917802989482...
# 17  [{'label': 'neutral', 'score': 0.8115255236625...
# 18  [{'label': 'positive', 'score': 0.980257093906...
# 19  [{'label': 'negative', 'score': 0.579171061515...
# 20  [{'label': 'negative', 'score': 0.500660002231...
# 21  [{'label': 'negative', 'score': 0.569909632205...
# 22  [{'label': 'neutral', 'score': 0.7545371651649...
# 23  [{'label': 'negative', 'score': 0.899666786193...
# 24  [{'label': 'neutral', 'score': 0.9064030647277...
# 25  [{'label': 'negative', 'score': 0.886918008327...
# 26  [{'label': 'neutral', 'score': 0.4997094869613...
# 27  [{'label': 'negative', 'score': 0.888863623142...
# 28  [{'label': 'neutral', 'score': 0.4131024181842...
# 29  [{'label': 'negative', 'score': 0.930119752883...

# %%
# Depending on the model used, it could be useful to remove stop words as well. The nltk library has a list of stop words
import nltk
from nltk.corpus import stopwords

def remove_stopwords(text):
    try:
        stop_words = set(stopwords.words('english'))
    except LookupError:
        nltk.download('stopwords')
        stop_words = set(stopwords.words('english'))
    stop_words = stopwords.words('english')
    return ' '.join(word for word in text.split() if word not in stop_words)

# %%
# The text needs to be tokenized and lemmatized before it can be used to train most most models
